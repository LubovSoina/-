# %%
from pyvis.network import Network
import networkx as nx
import ipywidgets as widgets
from ipywidgets import interact, interact_manual
import networkx as nx
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# script for clicks

# %% [markdown]
# select distinct uuid,untiID,l.createDT,title,description from ple.step_user_tracker_log l
# inner join rall.object o on objectUuid=o.uuid
# where l.type='click' and active=1 and useRecsys=1 and objectType='object' and untiID is not null

# %%
coursera=pd.read_excel('курсы ру и англ (1).xlsx')

# %%
coursera.small_field.nunique()
# Out:
# 46

# %%
course=pd.read_excel('cousre class.xlsx')

# %%
course
# Out:
#      Unnamed: 0  index                                  uuid  \
# 0             0      0  0d4e7302-0206-479b-ae83-e31dc3bae246
# 1             1      1  b6414e48-3406-4675-9ffd-6c7d79e6dba9
# 2             2      2  318afad6-8809-4adb-b0e5-f871d2061bf2
# 3             3      3  e966617d-736d-4c43-9ca1-75845cf1ddde
# 4             4      4  cbdb4bc2-e68b-48fb-a30d-4ca115ef5464
# ..          ...    ...                                   ...
# 905         905    945  b2d1d340-b904-4243-9fbe-a412fd309291
# 906         906    946  4afb75ad-44b4-4ea5-a82f-3f869722ae21
# 907         907    947  258f6a3f-55c1-4e08-b8a9-69cf17cf3dea
# 908         908    948  5eac994c-70a1-4424-8a50-70191e107ff0
# 909         909    949  ed5c7c3d-005a-4bee-9518-832ae244f086
#
#                                                  title  \
# 0                         Интернет-предпринимательство
# 1                                 Научная коммуникация
# 2              Национальная технологическая инициатива
# 3                              Открыть «Точку кипения»
# 4                            Управление университетами
# ..                                                 ...
# 905             Математика и Python для анализа данных
# 906                           Поиск структуры в данных
# 907                       Построение выводов по данным
# 908  Тренинг развитие креативного мышления – обучен...
# 909                      Креативное мышление в бизнесе
#
#                                                   text  \
# 0    Интернет-предпринимательство Курс разработан с...
# 1    Научная коммуникация Онлайн-курс о научной жур...
# 2    Национальная технологическая инициатива Содерж...
# 3    Открыть «Точку кипения» Курс посвящен тому, ка...
# 4    Управление университетами Это первый в мире on...
# ..                                                 ...
# 905  Математика и Python для анализа данных Анализ ...
# 906  Поиск структуры в данных В машинном обучении в...
# 907  Построение выводов по данным Влияет ли знание ...
# 908  Тренинг развитие креативного мышления – обучен...
# 909  Креативное мышление в бизнесе Онлайн-курс по к...
#
#                                              text_prep  \
# 0    интернет предпринимательство курс разработан с...
# 1    научная коммуникация онлайн курс о научной жур...
# 2    национальная технологическая инициатива содерж...
# 3    открыть «точку кипения» курс посвящен тому как...
# 4    управление университетами это первый в мире on...
# ..                                                 ...
# 905  математика и python для анализа данных анализ ...
# 906  поиск структуры в данных в машинном обучении в...
# 907  построение выводов по данным влияет ли знание ...
# 908  тренинг развитие креативного мышления – обучен...
# 909  креативное мышление в бизнесе онлайн курс по к...
#
#                                              text_stem           big_f  \
# 0    интернет предпринимательств разработа совместн...          Бизнес
# 1    научн коммуникац научн журналистик научн пиар ...  Наука о данных
# 2    национальн технологическ инициатив содержан ку...  Наука о данных
# 3    откр точк кипен посвящ том откр точк кипен поз...  Наука о данных
# 4    управлен университет перв мир трансформац унив...  Наука о данных
# ..                                                 ...             ...
# 905  математик python анализ дан анализ дан машин о...  Наука о данных
# 906  поиск структур дан машин обучен встреча задач ...  Наука о данных
# 907  построен вывод дан влия знан метод анализ дан ...  Наука о данных
# 908  тренинг развит креативн мышлен – обучен академ...  Наука о данных
# 909      креативн мышлен бизнес креативн мышлен бизнес          Бизнес
#
#                small_f
# 0       Основы бизнеса
# 1    Машинное обучение
# 2    Машинное обучение
# 3    Машинное обучение
# 4    Машинное обучение
# ..                 ...
# 905  Машинное обучение
# 906  Машинное обучение
# 907      Анализ данных
# 908  Машинное обучение
# 909   Бизнес-стратегия
#
# [910 rows x 9 columns]

# %%
course.big_f.nunique()
# Out:
# 11

# %%
df=pd.read_csv('курсы ралл клики.csv')

# %%
df.head()
# Out:
#                                    uuid  untiID             createDT  \
# 0  fb45ee38-6791-4468-a460-230248891877  138756  2020-04-21 09:28:04
# 1  8d980935-4db0-4ef2-a200-d56b13f6a9c3   10003  2020-04-21 09:54:51
# 2  7d775ae6-5ba1-4663-a843-672ac54446b7       3  2020-04-21 11:01:43
# 3  24796271-b020-44af-9c11-415636ece383       3  2020-04-21 11:01:58
# 4  7d775ae6-5ba1-4663-a843-672ac54446b7       3  2020-04-21 11:02:01
#
#                                                title      description
# 0  Универсальные компетенции в управлении техноло...  <p><br></p>\r\n
# 1                                     Основы дизайна  <p><br></p>\r\n
# 2               Основы эффективного делового общения  <p><br></p>\r\n
# 3                                        Тело лидера  <p><br></p>\r\n
# 4               Основы эффективного делового общения  <p><br></p>\r\n

# %%
df.sort_values(by='createDT')
# Out:
#                                        uuid  untiID             createDT  \
# 0      fb45ee38-6791-4468-a460-230248891877  138756  2020-04-21 09:28:04
# 1      8d980935-4db0-4ef2-a200-d56b13f6a9c3   10003  2020-04-21 09:54:51
# 2      7d775ae6-5ba1-4663-a843-672ac54446b7       3  2020-04-21 11:01:43
# 3      24796271-b020-44af-9c11-415636ece383       3  2020-04-21 11:01:58
# 4      7d775ae6-5ba1-4663-a843-672ac54446b7       3  2020-04-21 11:02:01
# ...                                     ...     ...                  ...
# 37085  82fb2609-6c7d-4acf-b117-6029164fef5f  154993  2021-06-20 11:20:52
# 37086  16462e4b-6357-4ebe-8cd9-375821f627d5  116536  2021-06-20 11:45:51
# 37087  f052926d-1ece-47f2-8367-c2a5503e061e  482246  2021-06-20 13:24:31
# 37088  f052926d-1ece-47f2-8367-c2a5503e061e  482246  2021-06-20 13:31:45
# 37089  e7e6c101-33ea-4355-bd31-1b0538169c55  484607  2021-06-20 14:08:35
#
#                                                    title  \
# 0      Универсальные компетенции в управлении техноло...
# 1                                         Основы дизайна
# 2                   Основы эффективного делового общения
# 3                                            Тело лидера
# 4                   Основы эффективного делового общения
# ...                                                  ...
# 37085                          Python для анализа данных
# 37086  Введение в теорию построения процедур множеств...
# 37087  Ready, Set, Future! Introduction to Futures Th...
# 37088  Ready, Set, Future! Introduction to Futures Th...
# 37089                       Профессия Python-разработчик
#
#                                              description
# 0                                        <p><br></p>\r\n
# 1                                        <p><br></p>\r\n
# 2                                        <p><br></p>\r\n
# 3                                        <p><br></p>\r\n
# 4                                        <p><br></p>\r\n
# ...                                                  ...
# 37085                                                NaN
# 37086                                                NaN
# 37087                                                NaN
# 37088                                                NaN
# 37089  На практике научитесь писать программы и разра...
#
# [37090 rows x 5 columns]

# %%
df.untiID.nunique()
# Out:
# 13813

# %%
df=df.merge(course,on='uuid',how='inner')

# %%
df.small_f.nunique()
# Out:
# 32

# %%
uuid_more2 = df.groupby('untiID').agg({'uuid':'nunique'}).query('uuid>1').reset_index()['untiID'].to_list()

# %%
df = df[df['untiID'].isin(uuid_more2)]

# %%
df = df.sort_values(by = ['untiID','createDT'])

# %%
df
# Out:
#                                       uuid  untiID             createDT  \
# 1096  ef6b3c28-5bfe-41d9-b5e1-1a7f4ba5b46d      55  2020-04-27 08:27:14
# 1618  e4680a7b-1658-4933-b5a8-86f3bb3179f5      55  2020-04-28 10:08:53
# 4855  f34dfc7b-6a49-423a-a347-fe1c8acec1e7      68  2020-07-26 10:39:09
# 4456  29f7aa34-4443-4c3b-af9a-5205684446a2      68  2020-07-26 10:48:51
# 98    fffc6e6d-6dca-44fe-81b5-7ea0977cdd6c      87  2020-04-23 09:02:38
# ...                                    ...     ...                  ...
# 1931  b7cd6cae-4117-474b-b0f1-1901066b3ae3  483054  2021-06-14 18:10:45
# 4226  5491abed-9ab3-4d8c-afd4-4d9200bdcb59  486755  2021-05-24 15:29:59
# 559   fffc6e6d-6dca-44fe-81b5-7ea0977cdd6c  486755  2021-05-24 15:43:15
# 6242  b605ae41-3853-42ff-8560-4484c7d36737  491734  2021-06-13 15:14:52
# 1392  814f3685-bb5f-4150-a221-7916d38f5aa5  491734  2021-06-14 06:46:20
#
#                                                 title_x  \
# 1096  Data science – обучение на курсе data scientis...
# 1618  Учимся учиться. Как преуспеть в школе, не трат...
# 4855  Оформление и защита прав на интеллектуальную с...
# 4456            Дизайн-библиотека | Bang Bang Education
# 98                         Основы проектного управления
# ...                                                 ...
# 1931                                     Самоменеджмент
# 4226  Бесплатный онлайн-курс по графическому дизайну...
# 559                        Основы проектного управления
# 6242          Информационное моделирование зданий (BIM)
# 1392  Как уверенно говорить на камеру, управляя свои...
#
#                                             description  Unnamed: 0  index  \
# 1096  Стань востребованным специалистом по data scie...         218    219
# 1618  Learn Учимся учиться. Как преуспеть в школе, н...         203    204
# 4855  Курс будет полезен менеджерам IT компаний, вла...         237    239
# 4456  <p>Онлайн-курсы, направленные на&nbsp;развитие...         183    184
# 98    <p>Курс посвящен изучению актуальных методов п...          35     35
# ...                                                 ...         ...    ...
# 1931  <p>Курс ориентирован на освоение технологий и ...          37     37
# 4226  Образовательный курс по графическому дизайну д...         197    198
# 559   <p>Курс посвящен изучению актуальных методов п...          35     35
# 6242  <p>Программа направлена на формирование и разв...         548    562
# 1392  <p>Всем, чья профессия и образ жизни связаны с...         235    237
#
#                                                 title_y  \
# 1096  Data science – обучение на курсе data scientis...
# 1618  Учимся учиться. Как преуспеть в школе, не трат...
# 4855  Оформление и защита прав на интеллектуальную с...
# 4456            Дизайн-библиотека | Bang Bang Education
# 98                         Основы проектного управления
# ...                                                 ...
# 1931                                     Самоменеджмент
# 4226  Бесплатный онлайн-курс по графическому дизайну...
# 559                        Основы проектного управления
# 6242          Информационное моделирование зданий (BIM)
# 1392  Как уверенно говорить на камеру, управляя свои...
#
#                                                    text  \
# 1096  Data science – обучение на курсе data scientis...
# 1618  Учимся учиться. Как преуспеть в школе, не трат...
# 4855  Оформление и защита прав на интеллектуальную с...
# 4456  Дизайн-библиотека | Bang Bang Education Онлайн...
# 98    Основы проектного управления Курс посвящен изу...
# ...                                                 ...
# 1931  Самоменеджмент Курс ориентирован на освоение т...
# 4226  Бесплатный онлайн-курс по графическому дизайну...
# 559   Основы проектного управления Курс посвящен изу...
# 6242  Информационное моделирование зданий (BIM) Прог...
# 1392  Как уверенно говорить на камеру, управляя свои...
#
#                                               text_prep  \
# 1096  data science – обучение на курсе data scientis...
# 1618  учимся учиться как преуспеть в школе не тратя ...
# 4855  оформление и защита прав на интеллектуальную с...
# 4456  дизайн библиотека bang bang education онлайн к...
# 98    основы проектного управления курс посвящен изу...
# ...                                                 ...
# 1931  самоменеджмент курс ориентирован на освоение т...
# 4226  бесплатный онлайн курс по графическому дизайну...
# 559   основы проектного управления курс посвящен изу...
# 6242  информационное моделирование зданий bim програ...
# 1392  как уверенно говорить на камеру управляя своим...
#
#                                               text_stem  \
# 1096  data science – обучен курс data scientist с ну...
# 1618  уч уч преуспет школ не трат все врем учеб cour...
# 4855  оформлен защит прав интеллектуальн собствен ин...
# 4456  дизайн библиотек bang bang education курс напр...
# 98    основ проектн управлен посвящ изучен актуальн ...
# ...                                                 ...
# 1931  самоменеджмент ориентирова освоен технолог тех...
# 4226  бесплатн графическ дизайн блок введен инструме...
# 559   основ проектн управлен посвящ изучен актуальн ...
# 6242  информацион моделирован здан bim программ напр...
# 1392  уверен говор камер управл сво ресурсн состоян ...
#
#                                  big_f                                small_f
# 1096                    Наука о данных        Теория вероятности и статистика
# 1618               Математика и логика                    Математика и логика
# 4855                Компьютерные науки  Разработка мобильных и веб-приложений
# 4456                            Бизнес                 Лидерство и менеджмент
# 98                            здоровье                  Фундаментальные науки
# ...                                ...                                    ...
# 1931  Естественные и технические науки            Механическое проектирование
# 4226    Гуманитарные науки и искусства                     Музыка и искусство
# 559                           здоровье                  Фундаментальные науки
# 6242  Естественные и технические науки                  Методики исследования
# 1392                   Личное развитие                        Личное развитие
#
# [2728 rows x 13 columns]

# %%
from sklearn import preprocessing

# %%
le = preprocessing.LabelEncoder()
df['obj_index'] = le.fit_transform(df['title_x'])

# %%
d=[]
for j in df.untiID.unique():
    g = df[df.untiID==j]
    b=[]
    for i in range(1,len(g)):
        c=[]
        c.append(int(g['obj_index'].values[i-1]))
        c.append(int(g['obj_index'].values[i]))
        b.append(c)
    d.append(b)

# %%
df.untiID.nunique()
# Out:
# 976

# %%
from tqdm import tqdm_notebook, tqdm

# %%
G = nx.MultiDiGraph()

for i in tqdm(range(len(d))):
    for j in range(len(d[i])):
        node = d[i][j]
        G.add_nodes_from(node)
for i in tqdm(range(len(d))):   
    edges = d[i]   
    G.add_edges_from(edges)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████| 976/976 [00:00<00:00, 325279.36it/s]
# 100%|████████████████████████████████████████████████████████████████████████████| 976/976 [00:00<00:00, 108328.90it/s]

# %%
from collections import Counter
width_dict = Counter(G.edges())
edge_width = [ (u, v,  value) 
              for ((u, v), value )  in width_dict.items() if (value>5 )& (u!=v)]

# %%
from1=[]
to1=[]
count=[]
for  i in edge_width:
    from1.append(i[0])
    to1.append (i[1])
    count.append(i[2])

# %%
graph_df=pd.DataFrame(data={'from1':from1,'to1':to1,'count':count})

# %%
graph_df
# Out:
#     from1  to1  count
# 0       8   71      8
# 1       8  147      9
# 2       8   72      8
# 3      42   59      6
# 4      42   66      9
# 5      42   25      9
# 6     102   24     13
# 7     102    7      9
# 8     102   25      6
# 9     102  141      7
# 10     61  167      9
# 11     27  142     10
# 12     54  130     12
# 13     54   42      9
# 14     24    7      7
# 15    137   67      7
# 16     25   59     93
# 17     25   66     16
# 18     25   42     44
# 19     25   21      6
# 20     59   42     28
# 21     59   66     15
# 22     59   25     11
# 23    167   44     12
# 24    121   54     10
# 25    121  130      8
# 26    111  131     19
# 27     21   48      7
# 28     21  137     12
# 29     21   67     15
# 30     21   72      8
# 31     98  157      8
# 32     71   21      6
# 33    122   50      8
# 34     32   25      8
# 35     32  118     17
# 36     32  117      8
# 37    141  131     18
# 38    141  168     23
# 39    141  111     35
# 40    141  102      9
# 41     66   25      8
# 42    118  120      8
# 43     67   48      9
# 44      2    4      7

# %%
c=graph_df.copy()

# %%
c=graph_df.merge(graph_df,how='left',left_on='to1',right_on='from1')

# %%
c
# Out:
#     from1_x  to1_x  count_x  from1_y  to1_y  count_y
# 0         8     71        8     71.0   21.0      6.0
# 1         8    147        9      NaN    NaN      NaN
# 2         8     72        8      NaN    NaN      NaN
# 3        42     59        6     59.0   42.0     28.0
# 4        42     59        6     59.0   66.0     15.0
# ..      ...    ...      ...      ...    ...      ...
# 78       66     25        8     25.0   42.0     44.0
# 79       66     25        8     25.0   21.0      6.0
# 80      118    120        8      NaN    NaN      NaN
# 81       67     48        9      NaN    NaN      NaN
# 82        2      4        7      NaN    NaN      NaN
#
# [83 rows x 6 columns]

# %%
m=c[(c.from1_x==c.to1_y) & (c.to1_x==c.from1_y)].copy()

# %%
for i in m.index:
    if m.loc[i,'count_x']>=m.loc[i,'count_y']:
        m.loc[i,'win']='x'
    else:
        m.loc[i,'win']='y'

# %%
m
# Out:
#     from1_x  to1_x  count_x  from1_y  to1_y  count_y win
# 3        42     59        6     59.0   42.0     28.0   y
# 9        42     25        9     25.0   42.0     44.0   y
# 20      102    141        7    141.0  102.0      9.0   y
# 31       25     59       93     59.0   25.0     11.0   x
# 32       25     66       16     66.0   25.0      8.0   x
# 35       25     42       44     42.0   25.0      9.0   x
# 40       59     42       28     42.0   59.0      6.0   x
# 44       59     25       11     25.0   59.0     93.0   y
# 75      141    102        9    102.0  141.0      7.0   x
# 77       66     25        8     25.0   66.0     16.0   y

# %%
m1=m.query('win=="y"')[['from1_x','to1_x']]

# %%
cc=graph_df.merge(m1,how='left',left_on=['from1','to1'],right_on=['from1_x','to1_x'])

# %%
cc=cc[cc['from1_x'].isna()][['from1','to1','count']]

# %%
cc['from1_title']=le.inverse_transform(cc['from1'])
cc['to1_title']=le.inverse_transform(cc['to1'])

# %%
graph_df=cc

# %%
graph_df.head()
# Out:
#    from1  to1  count                                        from1_title  \
# 0      8   71      8  Data science – обучение на курсе data scientis...
# 1      8  147      9  Data science – обучение на курсе data scientis...
# 2      8   72      8  Data science – обучение на курсе data scientis...
# 4     42   66      9            Дизайн-библиотека | Bang Bang Education
# 6    102   24     13                       Основы проектного управления
#
#                                           to1_title
# 0          Курс Python для работы с данными с нуля
# 1     Теория вероятностей для начинающих | Coursera
# 2           Курс SQL – обучение специалистов с нуля
# 4                    Курс - Дизайн в цифровой среде
# 6  Бесплатный онлайн-курс «Проджект менеджмент 101»

# %%
graph_df=graph_df.merge(course,left_on='from1_title',right_on='title',how='left').merge(course,left_on='to1_title',right_on='title',how='left')

# %%
graph_df.head()
# Out:
#    from1  to1  count                                        from1_title  \
# 0      8   71      8  Data science – обучение на курсе data scientis...
# 1      8  147      9  Data science – обучение на курсе data scientis...
# 2      8   72      8  Data science – обучение на курсе data scientis...
# 3     42   66      9            Дизайн-библиотека | Bang Bang Education
# 4    102   24     13                       Основы проектного управления
#
#                                           to1_title  Unnamed: 0_x  index_x  \
# 0          Курс Python для работы с данными с нуля            218      219
# 1     Теория вероятностей для начинающих | Coursera           218      219
# 2           Курс SQL – обучение специалистов с нуля           218      219
# 3                    Курс - Дизайн в цифровой среде           183      184
# 4  Бесплатный онлайн-курс «Проджект менеджмент 101»            35       35
#
#                                  uuid_x  \
# 0  ef6b3c28-5bfe-41d9-b5e1-1a7f4ba5b46d
# 1  ef6b3c28-5bfe-41d9-b5e1-1a7f4ba5b46d
# 2  ef6b3c28-5bfe-41d9-b5e1-1a7f4ba5b46d
# 3  29f7aa34-4443-4c3b-af9a-5205684446a2
# 4  fffc6e6d-6dca-44fe-81b5-7ea0977cdd6c
#
#                                              title_x  \
# 0  Data science – обучение на курсе data scientis...
# 1  Data science – обучение на курсе data scientis...
# 2  Data science – обучение на курсе data scientis...
# 3            Дизайн-библиотека | Bang Bang Education
# 4                       Основы проектного управления
#
#                                               text_x  ...  \
# 0  Data science – обучение на курсе data scientis...  ...
# 1  Data science – обучение на курсе data scientis...  ...
# 2  Data science – обучение на курсе data scientis...  ...
# 3  Дизайн-библиотека | Bang Bang Education Онлайн...  ...
# 4  Основы проектного управления Курс посвящен изу...  ...
#
#                          small_f_x Unnamed: 0_y index_y  \
# 0  Теория вероятности и статистика          220     221
# 1  Теория вероятности и статистика          216     217
# 2  Теория вероятности и статистика          219     220
# 3           Лидерство и менеджмент          254     257
# 4            Фундаментальные науки          182     183
#
#                                  uuid_y  \
# 0  43d9b8e9-2d0c-4541-92c5-37874000d098
# 1  0010ee34-fde3-4355-9089-c3cd1060ff7d
# 2  33e14c7e-0037-4c4a-8261-94af866bd5d8
# 3  f86d538e-c345-4cc4-b079-ccfed75bfe47
# 4  9c493b7c-166f-45e7-a7ce-31dd5a6bc0c7
#
#                                             title_y  \
# 0          Курс Python для работы с данными с нуля
# 1     Теория вероятностей для начинающих | Coursera
# 2           Курс SQL – обучение специалистов с нуля
# 3                    Курс - Дизайн в цифровой среде
# 4  Бесплатный онлайн-курс «Проджект менеджмент 101»
#
#                                               text_y  \
# 0  Курс Python для работы с данными с нуля  Вы на...
# 1  Теория вероятностей для начинающих | Coursera ...
# 2  Курс SQL – обучение специалистов с нуля Курс п...
# 3  Курс - Дизайн в цифровой среде Пройдя курс, вы...
# 4  Бесплатный онлайн-курс «Проджект менеджмент 10...
#
#                                          text_prep_y  \
# 0  курс python для работы с данными с нуля вы нау...
# 1  теория вероятностей для начинающих coursera le...
# 2  курс sql – обучение специалистов с нуля курс п...
# 3  курс дизайн в цифровой среде пройдя курс вы уз...
# 4  бесплатный онлайн курс «проджект менеджмент » ...
#
#                                          text_stem_y              big_f_y  \
# 0  python работ с дан с нул науч автоматизирова р...       Наука о данных
# 1  теор вероятн начина coursera learn теор вероят...  Математика и логика
# 2  sql – обучен специалист с нул баз дан sql начи...       Наука о данных
# 3  дизайн цифров сред пройд узна как этап состо р...               Бизнес
# 4  бесплатн проджект менеджмент получ базов знан ...               Бизнес
#
#              small_f_y
# 0        Анализ данных
# 1  Математика и логика
# 2    Машинное обучение
# 3  Физика и астрономия
# 4  Предпринимательство
#
# [5 rows x 23 columns]

# %%
graph_df.columns
# Out:
# Index(['from1', 'to1', 'count', 'from1_title', 'to1_title', 'Unnamed: 0_x',
#        'index_x', 'uuid_x', 'title_x', 'text_x', 'text_prep_x', 'text_stem_x',
#        'big_f_x', 'small_f_x', 'Unnamed: 0_y', 'index_y', 'uuid_y', 'title_y',
#        'text_y', 'text_prep_y', 'text_stem_y', 'big_f_y', 'small_f_y'],
#       dtype='object')

# %%
graph_df=graph_df[['from1', 'to1', 'count', 'title_x', 'title_y','big_f_x', 'small_f_x','big_f_y',
       'small_f_y']]

# %%
graph_df
# Out:
#     from1  to1  count                                            title_x  \
# 0       8   71      8  Data science – обучение на курсе data scientis...
# 1       8  147      9  Data science – обучение на курсе data scientis...
# 2       8   72      8  Data science – обучение на курсе data scientis...
# 3      42   66      9            Дизайн-библиотека | Bang Bang Education
# 4     102   24     13                       Основы проектного управления
# 5     102    7      9                       Основы проектного управления
# 6     102   25      6                       Основы проектного управления
# 7      61  167      9  Как уверенно говорить на камеру, управляя свои...
# 8      27  142     10                             Бизнес-тайм-менеджмент
# 9      54  130     12  Использование методов ТРИЗ для решения образов...
# 10     54   42      9  Использование методов ТРИЗ для решения образов...
# 11     24    7      7   Бесплатный онлайн-курс «Проджект менеджмент 101»
# 12    137   67      7                                  Старт в аналитике
# 13     25   59     93  Бесплатный онлайн-курс по графическому дизайну...
# 14     25   66     16  Бесплатный онлайн-курс по графическому дизайну...
# 15     25   42     44  Бесплатный онлайн-курс по графическому дизайну...
# 16     25   21      6  Бесплатный онлайн-курс по графическому дизайну...
# 17     59   42     28     Как стать дизайнером — бесплатный онлайн-курс
# 18     59   66     15     Как стать дизайнером — бесплатный онлайн-курс
# 19    167   44     12                          Эмбодимент: центрирование
# 20    121   54     10  Продвинутый курс развития креативности Creativ...
# 21    121  130      8  Продвинутый курс развития креативности Creativ...
# 22    111  131     19        Персональная эффективность: тайм-менеджмент
# 23     21   48      7  Аналитик данных – обучение с нуля на онлайн ку...
# 24     21  137     12  Аналитик данных – обучение с нуля на онлайн ку...
# 25     21   67     15  Аналитик данных – обучение с нуля на онлайн ку...
# 26     21   72      8  Аналитик данных – обучение с нуля на онлайн ку...
# 27     98  157      8            Онлайн-курс «Современное курсостроение»
# 28     71   21      6           Курс Python для работы с данными с нуля
# 29    122   50      8             Промышленный дизайн и 3D-моделирование
# 30    122   50      8             Промышленный дизайн и 3D-моделирование
# 31     32   25      8                  Введение в программирование (C++)
# 32     32   25      8                  Введение в программирование (C++)
# 33     32  118     17                  Введение в программирование (C++)
# 34     32  118     17                  Введение в программирование (C++)
# 35     32  118     17                  Введение в программирование (C++)
# 36     32  118     17                  Введение в программирование (C++)
# 37     32  118     17                  Введение в программирование (C++)
# 38     32  118     17                  Введение в программирование (C++)
# 39     32  117      8                  Введение в программирование (C++)
# 40     32  117      8                  Введение в программирование (C++)
# 41    141  131     18                                    Тайм-менеджмент
# 42    141  168     23                                    Тайм-менеджмент
# 43    141  111     35                                    Тайм-менеджмент
# 44    141  102      9                                    Тайм-менеджмент
# 45    118  120      8                         Программирование на Python
# 46    118  120      8                         Программирование на Python
# 47    118  120      8                         Программирование на Python
# 48     67   48      9         Курс BI аналитик – обучение анализу данных
# 49      2    4      7  &quot;Использование методов ТРИЗ для решения о...
#
#                                               title_y  \
# 0            Курс Python для работы с данными с нуля
# 1       Теория вероятностей для начинающих | Coursera
# 2             Курс SQL – обучение специалистов с нуля
# 3                      Курс - Дизайн в цифровой среде
# 4    Бесплатный онлайн-курс «Проджект менеджмент 101»
# 5   Agile и Scrum в работе над проектами и продукт...
# 6   Бесплатный онлайн-курс по графическому дизайну...
# 7                           Эмбодимент: центрирование
# 8   Тайм-менеджмент: простые способы управления вр...
# 9   Решение управленческих и технических задач мет...
# 10            Дизайн-библиотека | Bang Bang Education
# 11  Agile и Scrum в работе над проектами и продукт...
# 12         Курс BI аналитик – обучение анализу данных
# 13     Как стать дизайнером — бесплатный онлайн-курс
# 14                     Курс - Дизайн в цифровой среде
# 15            Дизайн-библиотека | Bang Bang Education
# 16  Аналитик данных – обучение с нуля на онлайн ку...
# 17            Дизайн-библиотека | Bang Bang Education
# 18                     Курс - Дизайн в цифровой среде
# 19       Забота о себе как навык телесного интеллекта
# 20  Использование методов ТРИЗ для решения образов...
# 21  Решение управленческих и технических задач мет...
# 22                                     Самоменеджмент
# 23  Интерактивное обучение работе с Microsoft Powe...
# 24                                  Старт в аналитике
# 25         Курс BI аналитик – обучение анализу данных
# 26            Курс SQL – обучение специалистов с нуля
# 27  Управление мотивацией участников онлайн-обучен...
# 28  Аналитик данных – обучение с нуля на онлайн ку...
# 29          Информационное моделирование зданий (BIM)
# 30          Информационное моделирование зданий (BIM)
# 31  Бесплатный онлайн-курс по графическому дизайну...
# 32  Бесплатный онлайн-курс по графическому дизайну...
# 33                         Программирование на Python
# 34                         Программирование на Python
# 35                         Программирование на Python
# 36                         Программирование на Python
# 37                         Программирование на Python
# 38                         Программирование на Python
# 39                             Программирование на C#
# 40                             Программирование на C#
# 41                                     Самоменеджмент
# 42                   Эффективная деловая коммуникация
# 43        Персональная эффективность: тайм-менеджмент
# 44                       Основы проектного управления
# 45                   Программирование на языке Python
# 46                   Программирование на языке Python
# 47                   Программирование на языке Python
# 48  Интерактивное обучение работе с Microsoft Powe...
# 49  &quot;Решение управленческих и технических зад...
#
#                            big_f_x                              small_f_x  \
# 0                   Наука о данных        Теория вероятности и статистика
# 1                   Наука о данных        Теория вероятности и статистика
# 2                   Наука о данных        Теория вероятности и статистика
# 3                           Бизнес                 Лидерство и менеджмент
# 4                         здоровье                  Фундаментальные науки
# 5                         здоровье                  Фундаментальные науки
# 6                         здоровье                  Фундаментальные науки
# 7                  Личное развитие                        Личное развитие
# 8                           Бизнес                 Лидерство и менеджмент
# 9                           Бизнес                 Лидерство и менеджмент
# 10                          Бизнес                 Лидерство и менеджмент
# 11                          Бизнес                    Предпринимательство
# 12                  Наука о данных                          Анализ данных
# 13  Гуманитарные науки и искусства                     Музыка и искусство
# 14  Гуманитарные науки и искусства                     Музыка и искусство
# 15  Гуманитарные науки и искусства                     Музыка и искусство
# 16  Гуманитарные науки и искусства                     Музыка и искусство
# 17                          Бизнес                    Предпринимательство
# 18                          Бизнес                    Предпринимательство
# 19                          Бизнес                         Основы бизнеса
# 20  Гуманитарные науки и искусства                     Музыка и искусство
# 21  Гуманитарные науки и искусства                     Музыка и искусство
# 22                          Бизнес                    Предпринимательство
# 23                  Наука о данных                          Анализ данных
# 24                  Наука о данных                          Анализ данных
# 25                  Наука о данных                          Анализ данных
# 26                  Наука о данных                          Анализ данных
# 27              Компьютерные науки                          Разработка ПО
# 28                  Наука о данных                          Анализ данных
# 29                Социальные науки                            Образование
# 30              Компьютерные науки                          Разработка ПО
# 31              Компьютерные науки                          Разработка ПО
# 32              Компьютерные науки                          Разработка ПО
# 33              Компьютерные науки                          Разработка ПО
# 34              Компьютерные науки                          Разработка ПО
# 35              Компьютерные науки                          Разработка ПО
# 36              Компьютерные науки                          Разработка ПО
# 37              Компьютерные науки                          Разработка ПО
# 38              Компьютерные науки                          Разработка ПО
# 39              Компьютерные науки                          Разработка ПО
# 40              Компьютерные науки                          Разработка ПО
# 41                 Личное развитие                        Личное развитие
# 42                 Личное развитие                        Личное развитие
# 43                 Личное развитие                        Личное развитие
# 44                 Личное развитие                        Личное развитие
# 45              Компьютерные науки                          Разработка ПО
# 46              Компьютерные науки                              Алгоритмы
# 47              Компьютерные науки  Разработка мобильных и веб-приложений
# 48                  Наука о данных                          Анализ данных
# 49                          Бизнес                 Лидерство и менеджмент
#
#                              big_f_y                              small_f_y
# 0                     Наука о данных                          Анализ данных
# 1                Математика и логика                    Математика и логика
# 2                     Наука о данных                      Машинное обучение
# 3                             Бизнес                    Физика и астрономия
# 4                             Бизнес                    Предпринимательство
# 5                             Бизнес                              Маркетинг
# 6     Гуманитарные науки и искусства                     Музыка и искусство
# 7                             Бизнес                         Основы бизнеса
# 8                 Компьютерные науки  Разработка мобильных и веб-приложений
# 9                           здоровье                Медицинская информатика
# 10                            Бизнес                 Лидерство и менеджмент
# 11                            Бизнес                              Маркетинг
# 12                    Наука о данных                          Анализ данных
# 13                            Бизнес                    Предпринимательство
# 14                            Бизнес                    Физика и астрономия
# 15                            Бизнес                 Лидерство и менеджмент
# 16                    Наука о данных                          Анализ данных
# 17                            Бизнес                 Лидерство и менеджмент
# 18                            Бизнес                    Физика и астрономия
# 19                            Бизнес                    Предпринимательство
# 20                            Бизнес                 Лидерство и менеджмент
# 21                          здоровье                Медицинская информатика
# 22  Естественные и технические науки            Механическое проектирование
# 23                    Наука о данных                      Машинное обучение
# 24                    Наука о данных                          Анализ данных
# 25                    Наука о данных                          Анализ данных
# 26                    Наука о данных                      Машинное обучение
# 27                    Наука о данных                      Машинное обучение
# 28                    Наука о данных                          Анализ данных
# 29  Естественные и технические науки                  Методики исследования
# 30  Естественные и технические науки                  Методики исследования
# 31    Гуманитарные науки и искусства                     Музыка и искусство
# 32    Гуманитарные науки и искусства                     Музыка и искусство
# 33                Компьютерные науки                          Разработка ПО
# 34                Компьютерные науки                              Алгоритмы
# 35                Компьютерные науки  Разработка мобильных и веб-приложений
# 36                Компьютерные науки                          Разработка ПО
# 37                Компьютерные науки                              Алгоритмы
# 38                Компьютерные науки  Разработка мобильных и веб-приложений
# 39                Компьютерные науки                          Разработка ПО
# 40                Компьютерные науки                          Разработка ПО
# 41  Естественные и технические науки            Механическое проектирование
# 42                   Личное развитие                        Личное развитие
# 43                            Бизнес                    Предпринимательство
# 44                          здоровье                  Фундаментальные науки
# 45                Компьютерные науки                          Разработка ПО
# 46                Компьютерные науки                          Разработка ПО
# 47                Компьютерные науки                          Разработка ПО
# 48                    Наука о данных                      Машинное обучение
# 49                          здоровье                             Психология

# %%
graph_df1= graph_df.groupby(['big_f_x','small_f_x','big_f_y','small_f_y'])['count'].sum().reset_index().copy()

# %%
cl=graph_df1.merge(graph_df1,how='left',left_on='small_f_y',right_on='small_f_x')

# %%
mm1=cl[(cl.small_f_x_x==cl.small_f_y_y) & (cl.small_f_y_x==cl.small_f_x_y)]

# %%
for i in mm1.index:
    if mm1.loc[i,'count_x']>=mm1.loc[i,'count_y']:
        mm1.loc[i,'win']='x'
    else:
        mm1.loc[i,'win']='y'
# Out:
# <ipython-input-52-eed2f25b68c9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   mm1.loc[i,'win']='x'

# %%
mmm1=mm1.query('win=="y"')[['big_f_x_x','small_f_x_x','big_f_y_x','small_f_y_x']]

# %%
gg=graph_df1.merge(mmm1,how='left',left_on=['big_f_x','small_f_x','big_f_y','small_f_y'],right_on=['big_f_x_x','small_f_x_x','big_f_y_x','small_f_y_x'])

# %%
gg.columns
# Out:
# Index(['big_f_x', 'small_f_x', 'big_f_y', 'small_f_y', 'count', 'big_f_x_x',
#        'small_f_x_x', 'big_f_y_x', 'small_f_y_x'],
#       dtype='object')

# %%
gg=gg[gg['small_f_x_x'].isna()][['big_f_x', 'small_f_x', 'big_f_y', 'small_f_y', 'count']]

# %%
graph_df1=gg

# %%
G_new = nx.DiGraph()

# %%
edge_width = [ (u2, u4,  {'width': value/100}) 
              for (u1, u2,u3,u4, value )  in graph_df1.to_records(index=False) if u2!=u4]

# %%
G_new.add_edges_from(edge_width,title='')

# %%
pd.concat([graph_df.title_y,graph_df.title_x]).nunique()
# Out:
# 37

# %%
graph_df
# Out:
#     from1  to1  count                                            title_x  \
# 0       8   71      8  Data science – обучение на курсе data scientis...
# 1       8  147      9  Data science – обучение на курсе data scientis...
# 2       8   72      8  Data science – обучение на курсе data scientis...
# 3      42   66      9            Дизайн-библиотека | Bang Bang Education
# 4     102   24     13                       Основы проектного управления
# 5     102    7      9                       Основы проектного управления
# 6     102   25      6                       Основы проектного управления
# 7      61  167      9  Как уверенно говорить на камеру, управляя свои...
# 8      27  142     10                             Бизнес-тайм-менеджмент
# 9      54  130     12  Использование методов ТРИЗ для решения образов...
# 10     54   42      9  Использование методов ТРИЗ для решения образов...
# 11     24    7      7   Бесплатный онлайн-курс «Проджект менеджмент 101»
# 12    137   67      7                                  Старт в аналитике
# 13     25   59     93  Бесплатный онлайн-курс по графическому дизайну...
# 14     25   66     16  Бесплатный онлайн-курс по графическому дизайну...
# 15     25   42     44  Бесплатный онлайн-курс по графическому дизайну...
# 16     25   21      6  Бесплатный онлайн-курс по графическому дизайну...
# 17     59   42     28     Как стать дизайнером — бесплатный онлайн-курс
# 18     59   66     15     Как стать дизайнером — бесплатный онлайн-курс
# 19    167   44     12                          Эмбодимент: центрирование
# 20    121   54     10  Продвинутый курс развития креативности Creativ...
# 21    121  130      8  Продвинутый курс развития креативности Creativ...
# 22    111  131     19        Персональная эффективность: тайм-менеджмент
# 23     21   48      7  Аналитик данных – обучение с нуля на онлайн ку...
# 24     21  137     12  Аналитик данных – обучение с нуля на онлайн ку...
# 25     21   67     15  Аналитик данных – обучение с нуля на онлайн ку...
# 26     21   72      8  Аналитик данных – обучение с нуля на онлайн ку...
# 27     98  157      8            Онлайн-курс «Современное курсостроение»
# 28     71   21      6           Курс Python для работы с данными с нуля
# 29    122   50      8             Промышленный дизайн и 3D-моделирование
# 30    122   50      8             Промышленный дизайн и 3D-моделирование
# 31     32   25      8                  Введение в программирование (C++)
# 32     32   25      8                  Введение в программирование (C++)
# 33     32  118     17                  Введение в программирование (C++)
# 34     32  118     17                  Введение в программирование (C++)
# 35     32  118     17                  Введение в программирование (C++)
# 36     32  118     17                  Введение в программирование (C++)
# 37     32  118     17                  Введение в программирование (C++)
# 38     32  118     17                  Введение в программирование (C++)
# 39     32  117      8                  Введение в программирование (C++)
# 40     32  117      8                  Введение в программирование (C++)
# 41    141  131     18                                    Тайм-менеджмент
# 42    141  168     23                                    Тайм-менеджмент
# 43    141  111     35                                    Тайм-менеджмент
# 44    141  102      9                                    Тайм-менеджмент
# 45    118  120      8                         Программирование на Python
# 46    118  120      8                         Программирование на Python
# 47    118  120      8                         Программирование на Python
# 48     67   48      9         Курс BI аналитик – обучение анализу данных
# 49      2    4      7  &quot;Использование методов ТРИЗ для решения о...
#
#                                               title_y  \
# 0            Курс Python для работы с данными с нуля
# 1       Теория вероятностей для начинающих | Coursera
# 2             Курс SQL – обучение специалистов с нуля
# 3                      Курс - Дизайн в цифровой среде
# 4    Бесплатный онлайн-курс «Проджект менеджмент 101»
# 5   Agile и Scrum в работе над проектами и продукт...
# 6   Бесплатный онлайн-курс по графическому дизайну...
# 7                           Эмбодимент: центрирование
# 8   Тайм-менеджмент: простые способы управления вр...
# 9   Решение управленческих и технических задач мет...
# 10            Дизайн-библиотека | Bang Bang Education
# 11  Agile и Scrum в работе над проектами и продукт...
# 12         Курс BI аналитик – обучение анализу данных
# 13     Как стать дизайнером — бесплатный онлайн-курс
# 14                     Курс - Дизайн в цифровой среде
# 15            Дизайн-библиотека | Bang Bang Education
# 16  Аналитик данных – обучение с нуля на онлайн ку...
# 17            Дизайн-библиотека | Bang Bang Education
# 18                     Курс - Дизайн в цифровой среде
# 19       Забота о себе как навык телесного интеллекта
# 20  Использование методов ТРИЗ для решения образов...
# 21  Решение управленческих и технических задач мет...
# 22                                     Самоменеджмент
# 23  Интерактивное обучение работе с Microsoft Powe...
# 24                                  Старт в аналитике
# 25         Курс BI аналитик – обучение анализу данных
# 26            Курс SQL – обучение специалистов с нуля
# 27  Управление мотивацией участников онлайн-обучен...
# 28  Аналитик данных – обучение с нуля на онлайн ку...
# 29          Информационное моделирование зданий (BIM)
# 30          Информационное моделирование зданий (BIM)
# 31  Бесплатный онлайн-курс по графическому дизайну...
# 32  Бесплатный онлайн-курс по графическому дизайну...
# 33                         Программирование на Python
# 34                         Программирование на Python
# 35                         Программирование на Python
# 36                         Программирование на Python
# 37                         Программирование на Python
# 38                         Программирование на Python
# 39                             Программирование на C#
# 40                             Программирование на C#
# 41                                     Самоменеджмент
# 42                   Эффективная деловая коммуникация
# 43        Персональная эффективность: тайм-менеджмент
# 44                       Основы проектного управления
# 45                   Программирование на языке Python
# 46                   Программирование на языке Python
# 47                   Программирование на языке Python
# 48  Интерактивное обучение работе с Microsoft Powe...
# 49  &quot;Решение управленческих и технических зад...
#
#                            big_f_x                              small_f_x  \
# 0                   Наука о данных        Теория вероятности и статистика
# 1                   Наука о данных        Теория вероятности и статистика
# 2                   Наука о данных        Теория вероятности и статистика
# 3                           Бизнес                 Лидерство и менеджмент
# 4                         здоровье                  Фундаментальные науки
# 5                         здоровье                  Фундаментальные науки
# 6                         здоровье                  Фундаментальные науки
# 7                  Личное развитие                        Личное развитие
# 8                           Бизнес                 Лидерство и менеджмент
# 9                           Бизнес                 Лидерство и менеджмент
# 10                          Бизнес                 Лидерство и менеджмент
# 11                          Бизнес                    Предпринимательство
# 12                  Наука о данных                          Анализ данных
# 13  Гуманитарные науки и искусства                     Музыка и искусство
# 14  Гуманитарные науки и искусства                     Музыка и искусство
# 15  Гуманитарные науки и искусства                     Музыка и искусство
# 16  Гуманитарные науки и искусства                     Музыка и искусство
# 17                          Бизнес                    Предпринимательство
# 18                          Бизнес                    Предпринимательство
# 19                          Бизнес                         Основы бизнеса
# 20  Гуманитарные науки и искусства                     Музыка и искусство
# 21  Гуманитарные науки и искусства                     Музыка и искусство
# 22                          Бизнес                    Предпринимательство
# 23                  Наука о данных                          Анализ данных
# 24                  Наука о данных                          Анализ данных
# 25                  Наука о данных                          Анализ данных
# 26                  Наука о данных                          Анализ данных
# 27              Компьютерные науки                          Разработка ПО
# 28                  Наука о данных                          Анализ данных
# 29                Социальные науки                            Образование
# 30              Компьютерные науки                          Разработка ПО
# 31              Компьютерные науки                          Разработка ПО
# 32              Компьютерные науки                          Разработка ПО
# 33              Компьютерные науки                          Разработка ПО
# 34              Компьютерные науки                          Разработка ПО
# 35              Компьютерные науки                          Разработка ПО
# 36              Компьютерные науки                          Разработка ПО
# 37              Компьютерные науки                          Разработка ПО
# 38              Компьютерные науки                          Разработка ПО
# 39              Компьютерные науки                          Разработка ПО
# 40              Компьютерные науки                          Разработка ПО
# 41                 Личное развитие                        Личное развитие
# 42                 Личное развитие                        Личное развитие
# 43                 Личное развитие                        Личное развитие
# 44                 Личное развитие                        Личное развитие
# 45              Компьютерные науки                          Разработка ПО
# 46              Компьютерные науки                              Алгоритмы
# 47              Компьютерные науки  Разработка мобильных и веб-приложений
# 48                  Наука о данных                          Анализ данных
# 49                          Бизнес                 Лидерство и менеджмент
#
#                              big_f_y                              small_f_y
# 0                     Наука о данных                          Анализ данных
# 1                Математика и логика                    Математика и логика
# 2                     Наука о данных                      Машинное обучение
# 3                             Бизнес                    Физика и астрономия
# 4                             Бизнес                    Предпринимательство
# 5                             Бизнес                              Маркетинг
# 6     Гуманитарные науки и искусства                     Музыка и искусство
# 7                             Бизнес                         Основы бизнеса
# 8                 Компьютерные науки  Разработка мобильных и веб-приложений
# 9                           здоровье                Медицинская информатика
# 10                            Бизнес                 Лидерство и менеджмент
# 11                            Бизнес                              Маркетинг
# 12                    Наука о данных                          Анализ данных
# 13                            Бизнес                    Предпринимательство
# 14                            Бизнес                    Физика и астрономия
# 15                            Бизнес                 Лидерство и менеджмент
# 16                    Наука о данных                          Анализ данных
# 17                            Бизнес                 Лидерство и менеджмент
# 18                            Бизнес                    Физика и астрономия
# 19                            Бизнес                    Предпринимательство
# 20                            Бизнес                 Лидерство и менеджмент
# 21                          здоровье                Медицинская информатика
# 22  Естественные и технические науки            Механическое проектирование
# 23                    Наука о данных                      Машинное обучение
# 24                    Наука о данных                          Анализ данных
# 25                    Наука о данных                          Анализ данных
# 26                    Наука о данных                      Машинное обучение
# 27                    Наука о данных                      Машинное обучение
# 28                    Наука о данных                          Анализ данных
# 29  Естественные и технические науки                  Методики исследования
# 30  Естественные и технические науки                  Методики исследования
# 31    Гуманитарные науки и искусства                     Музыка и искусство
# 32    Гуманитарные науки и искусства                     Музыка и искусство
# 33                Компьютерные науки                          Разработка ПО
# 34                Компьютерные науки                              Алгоритмы
# 35                Компьютерные науки  Разработка мобильных и веб-приложений
# 36                Компьютерные науки                          Разработка ПО
# 37                Компьютерные науки                              Алгоритмы
# 38                Компьютерные науки  Разработка мобильных и веб-приложений
# 39                Компьютерные науки                          Разработка ПО
# 40                Компьютерные науки                          Разработка ПО
# 41  Естественные и технические науки            Механическое проектирование
# 42                   Личное развитие                        Личное развитие
# 43                            Бизнес                    Предпринимательство
# 44                          здоровье                  Фундаментальные науки
# 45                Компьютерные науки                          Разработка ПО
# 46                Компьютерные науки                          Разработка ПО
# 47                Компьютерные науки                          Разработка ПО
# 48                    Наука о данных                      Машинное обучение
# 49                          здоровье                             Психология

# %%
nt = Network(height="500px", width="100%", bgcolor="#222222", font_color="white", notebook=True,directed=True)

nt.add_nodes(list(G_new.nodes),                     
                       )
nt.from_nx(G_new)
for edge in nt.edges:
        
        edge['title']='Количество переходов'+' ' +str(int(edge['width']*100))

# %%
list(G_new.nodes)
# Out:
# ['Лидерство и менеджмент',
#  'Бизнес-стратегия',
#  'Маркетинг',
#  'Основы бизнеса',
#  'Музыка и искусство',
#  'Философия',
#  'Дизайн и продукт',
#  'Личное развитие',
#  'Машинное обучение',
#  'Образование',
#  'Психология',
#  'Другие языки',
#  'Компьютерная безопасность и сети',
#  'Алгоритмы',
#  'Разработка ПО',
#  'Анализ данных',
#  'Теория вероятности и статистика',
#  'Фундаментальные науки',
#  'Предпринимательство',
#  'Математика и логика',
#  'Финансы',
#  'История',
#  'Методики исследования',
#  'Механическое проектирование',
#  'Экологические исследования и устойчивое развитие',
#  'Государственное управление и общество',
#  'Экономика',
#  'Управление данными',
#  'Физика и астрономия',
#  'Разработка мобильных и веб-приложений',
#  'Медицинская информатика',
#  'Юриспруденция']

# %%
nt.show('граф с кластерами.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="граф с кластерами.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
colors=pd.read_excel('color class (2).xlsx')[['small_f_x','Unnamed: 3']]

# %%
d_color=dict(colors.values)

# %%
d_color['Бизнес-стратегия']
# Out:
# '#9799cc'

# %%
graph_df.query('small_f_x=="Другие языки"').values
# Out:
# array([], shape=(0, 9), dtype=object)

# %%
graph_df=graph_df[['from1','to1','title_x','title_y','big_f_x','small_f_x','big_f_y','small_f_y','count']]

# %%
graph_df
# Out:
#     from1  to1                                            title_x  \
# 0       8   71  Data science – обучение на курсе data scientis...
# 1     137   67                                  Старт в аналитике
# 2      21  137  Аналитик данных – обучение с нуля на онлайн ку...
# 3      21   67  Аналитик данных – обучение с нуля на онлайн ку...
# 4      71   21           Курс Python для работы с данными с нуля
# 5      25   21  Бесплатный онлайн-курс по графическому дизайну...
# 6       8  147  Data science – обучение на курсе data scientis...
# 7       8   72  Data science – обучение на курсе data scientis...
# 8      21   48  Аналитик данных – обучение с нуля на онлайн ку...
# 9      21   72  Аналитик данных – обучение с нуля на онлайн ку...
# 10     67   48         Курс BI аналитик – обучение анализу данных
# 11     98  157            Онлайн-курс «Современное курсостроение»
# 12     42   66            Дизайн-библиотека | Bang Bang Education
# 13     59   66     Как стать дизайнером — бесплатный онлайн-курс
# 14     25   66  Бесплатный онлайн-курс по графическому дизайну...
# 15     27  142                             Бизнес-тайм-менеджмент
# 16     32  118                  Введение в программирование (C++)
# 17     32  118                  Введение в программирование (C++)
# 18     54  130  Использование методов ТРИЗ для решения образов...
# 19    121  130  Продвинутый курс развития креативности Creativ...
# 20     54   42  Использование методов ТРИЗ для решения образов...
# 21     59   42     Как стать дизайнером — бесплатный онлайн-курс
# 22     25   42  Бесплатный онлайн-курс по графическому дизайну...
# 23    121   54  Продвинутый курс развития креативности Creativ...
# 24      2    4  &quot;Использование методов ТРИЗ для решения о...
# 25    102   24                       Основы проектного управления
# 26    141  111                                    Тайм-менеджмент
# 27     25   59  Бесплатный онлайн-курс по графическому дизайну...
# 28    167   44                          Эмбодимент: центрирование
# 29    102    7                       Основы проектного управления
# 30     24    7   Бесплатный онлайн-курс «Проджект менеджмент 101»
# 31    102   25                       Основы проектного управления
# 32     32   25                  Введение в программирование (C++)
# 33     32   25                  Введение в программирование (C++)
# 34     61  167  Как уверенно говорить на камеру, управляя свои...
# 35    141  131                                    Тайм-менеджмент
# 36    111  131        Персональная эффективность: тайм-менеджмент
# 37    141  168                                    Тайм-менеджмент
# 38    141  102                                    Тайм-менеджмент
# 39    122   50             Промышленный дизайн и 3D-моделирование
# 40    122   50             Промышленный дизайн и 3D-моделирование
# 41     32  118                  Введение в программирование (C++)
# 42     32  118                  Введение в программирование (C++)
# 43     32  117                  Введение в программирование (C++)
# 44     32  117                  Введение в программирование (C++)
# 45    118  120                         Программирование на Python
# 46    118  120                         Программирование на Python
# 47    118  120                         Программирование на Python
# 48     32  118                  Введение в программирование (C++)
# 49     32  118                  Введение в программирование (C++)
#
#                                               title_y  \
# 0            Курс Python для работы с данными с нуля
# 1          Курс BI аналитик – обучение анализу данных
# 2                                   Старт в аналитике
# 3          Курс BI аналитик – обучение анализу данных
# 4   Аналитик данных – обучение с нуля на онлайн ку...
# 5   Аналитик данных – обучение с нуля на онлайн ку...
# 6       Теория вероятностей для начинающих | Coursera
# 7             Курс SQL – обучение специалистов с нуля
# 8   Интерактивное обучение работе с Microsoft Powe...
# 9             Курс SQL – обучение специалистов с нуля
# 10  Интерактивное обучение работе с Microsoft Powe...
# 11  Управление мотивацией участников онлайн-обучен...
# 12                     Курс - Дизайн в цифровой среде
# 13                     Курс - Дизайн в цифровой среде
# 14                     Курс - Дизайн в цифровой среде
# 15  Тайм-менеджмент: простые способы управления вр...
# 16                         Программирование на Python
# 17                         Программирование на Python
# 18  Решение управленческих и технических задач мет...
# 19  Решение управленческих и технических задач мет...
# 20            Дизайн-библиотека | Bang Bang Education
# 21            Дизайн-библиотека | Bang Bang Education
# 22            Дизайн-библиотека | Bang Bang Education
# 23  Использование методов ТРИЗ для решения образов...
# 24  &quot;Решение управленческих и технических зад...
# 25   Бесплатный онлайн-курс «Проджект менеджмент 101»
# 26        Персональная эффективность: тайм-менеджмент
# 27     Как стать дизайнером — бесплатный онлайн-курс
# 28       Забота о себе как навык телесного интеллекта
# 29  Agile и Scrum в работе над проектами и продукт...
# 30  Agile и Scrum в работе над проектами и продукт...
# 31  Бесплатный онлайн-курс по графическому дизайну...
# 32  Бесплатный онлайн-курс по графическому дизайну...
# 33  Бесплатный онлайн-курс по графическому дизайну...
# 34                          Эмбодимент: центрирование
# 35                                     Самоменеджмент
# 36                                     Самоменеджмент
# 37                   Эффективная деловая коммуникация
# 38                       Основы проектного управления
# 39          Информационное моделирование зданий (BIM)
# 40          Информационное моделирование зданий (BIM)
# 41                         Программирование на Python
# 42                         Программирование на Python
# 43                             Программирование на C#
# 44                             Программирование на C#
# 45                   Программирование на языке Python
# 46                   Программирование на языке Python
# 47                   Программирование на языке Python
# 48                         Программирование на Python
# 49                         Программирование на Python
#
#                            big_f_x                              small_f_x  \
# 0                   Наука о данных        Теория вероятности и статистика
# 1                   Наука о данных                          Анализ данных
# 2                   Наука о данных                          Анализ данных
# 3                   Наука о данных                          Анализ данных
# 4                   Наука о данных                          Анализ данных
# 5   Гуманитарные науки и искусства                     Музыка и искусство
# 6                   Наука о данных        Теория вероятности и статистика
# 7                   Наука о данных        Теория вероятности и статистика
# 8                   Наука о данных                          Анализ данных
# 9                   Наука о данных                          Анализ данных
# 10                  Наука о данных                          Анализ данных
# 11              Компьютерные науки                          Разработка ПО
# 12                          Бизнес                 Лидерство и менеджмент
# 13                          Бизнес                    Предпринимательство
# 14  Гуманитарные науки и искусства                     Музыка и искусство
# 15                          Бизнес                 Лидерство и менеджмент
# 16              Компьютерные науки                          Разработка ПО
# 17              Компьютерные науки                          Разработка ПО
# 18                          Бизнес                 Лидерство и менеджмент
# 19  Гуманитарные науки и искусства                     Музыка и искусство
# 20                          Бизнес                 Лидерство и менеджмент
# 21                          Бизнес                    Предпринимательство
# 22  Гуманитарные науки и искусства                     Музыка и искусство
# 23  Гуманитарные науки и искусства                     Музыка и искусство
# 24                          Бизнес                 Лидерство и менеджмент
# 25                        здоровье                  Фундаментальные науки
# 26                 Личное развитие                        Личное развитие
# 27  Гуманитарные науки и искусства                     Музыка и искусство
# 28                          Бизнес                         Основы бизнеса
# 29                        здоровье                  Фундаментальные науки
# 30                          Бизнес                    Предпринимательство
# 31                        здоровье                  Фундаментальные науки
# 32              Компьютерные науки                          Разработка ПО
# 33              Компьютерные науки                          Разработка ПО
# 34                 Личное развитие                        Личное развитие
# 35                 Личное развитие                        Личное развитие
# 36                          Бизнес                    Предпринимательство
# 37                 Личное развитие                        Личное развитие
# 38                 Личное развитие                        Личное развитие
# 39              Компьютерные науки                          Разработка ПО
# 40                Социальные науки                            Образование
# 41              Компьютерные науки                          Разработка ПО
# 42              Компьютерные науки                          Разработка ПО
# 43              Компьютерные науки                          Разработка ПО
# 44              Компьютерные науки                          Разработка ПО
# 45              Компьютерные науки                          Разработка ПО
# 46              Компьютерные науки                              Алгоритмы
# 47              Компьютерные науки  Разработка мобильных и веб-приложений
# 48              Компьютерные науки                          Разработка ПО
# 49              Компьютерные науки                          Разработка ПО
#
#                              big_f_y                              small_f_y  \
# 0                     Наука о данных                          Анализ данных
# 1                     Наука о данных                          Анализ данных
# 2                     Наука о данных                          Анализ данных
# 3                     Наука о данных                          Анализ данных
# 4                     Наука о данных                          Анализ данных
# 5                     Наука о данных                          Анализ данных
# 6                Математика и логика                    Математика и логика
# 7                     Наука о данных                      Машинное обучение
# 8                     Наука о данных                      Машинное обучение
# 9                     Наука о данных                      Машинное обучение
# 10                    Наука о данных                      Машинное обучение
# 11                    Наука о данных                      Машинное обучение
# 12                            Бизнес                    Физика и астрономия
# 13                            Бизнес                    Физика и астрономия
# 14                            Бизнес                    Физика и астрономия
# 15                Компьютерные науки  Разработка мобильных и веб-приложений
# 16                Компьютерные науки  Разработка мобильных и веб-приложений
# 17                Компьютерные науки  Разработка мобильных и веб-приложений
# 18                          здоровье                Медицинская информатика
# 19                          здоровье                Медицинская информатика
# 20                            Бизнес                 Лидерство и менеджмент
# 21                            Бизнес                 Лидерство и менеджмент
# 22                            Бизнес                 Лидерство и менеджмент
# 23                            Бизнес                 Лидерство и менеджмент
# 24                          здоровье                             Психология
# 25                            Бизнес                    Предпринимательство
# 26                            Бизнес                    Предпринимательство
# 27                            Бизнес                    Предпринимательство
# 28                            Бизнес                    Предпринимательство
# 29                            Бизнес                              Маркетинг
# 30                            Бизнес                              Маркетинг
# 31    Гуманитарные науки и искусства                     Музыка и искусство
# 32    Гуманитарные науки и искусства                     Музыка и искусство
# 33    Гуманитарные науки и искусства                     Музыка и искусство
# 34                            Бизнес                         Основы бизнеса
# 35  Естественные и технические науки            Механическое проектирование
# 36  Естественные и технические науки            Механическое проектирование
# 37                   Личное развитие                        Личное развитие
# 38                          здоровье                  Фундаментальные науки
# 39  Естественные и технические науки                  Методики исследования
# 40  Естественные и технические науки                  Методики исследования
# 41                Компьютерные науки                          Разработка ПО
# 42                Компьютерные науки                          Разработка ПО
# 43                Компьютерные науки                          Разработка ПО
# 44                Компьютерные науки                          Разработка ПО
# 45                Компьютерные науки                          Разработка ПО
# 46                Компьютерные науки                          Разработка ПО
# 47                Компьютерные науки                          Разработка ПО
# 48                Компьютерные науки                              Алгоритмы
# 49                Компьютерные науки                              Алгоритмы
#
#     count
# 0       8
# 1       7
# 2      12
# 3      15
# 4       6
# 5       6
# 6       9
# 7       8
# 8       7
# 9       8
# 10      9
# 11      8
# 12      9
# 13     15
# 14     16
# 15     10
# 16     17
# 17     17
# 18     12
# 19      8
# 20      9
# 21     28
# 22     44
# 23     10
# 24      7
# 25     13
# 26     35
# 27     93
# 28     12
# 29      9
# 30      7
# 31      6
# 32      8
# 33      8
# 34      9
# 35     18
# 36     19
# 37     23
# 38      9
# 39      8
# 40      8
# 41     17
# 42     17
# 43      8
# 44      8
# 45      8
# 46      8
# 47      8
# 48     17
# 49     17

# %%
@interact
def main(INIT_ROLE = list(graph_df.title_x.unique())):
    
    c=[]
    G_new = nx.DiGraph()
    res=graph_df.query('title_x==@INIT_ROLE')
    res=res.sort_values(by='count',ascending=False).head(5)
    a=res.values.tolist()
    for gg in a:
        c.append(gg[1])
        c.append(gg[0])

    edge_width = [ (m,n,  {'width': value/10}) 
              for (u, v,m,n,a1,a2,a3,a4, value)  in a if m!=n]
  

    G_new.add_edges_from(edge_width,title='')
   
    try:
        for  i in range(10):
               
            res=graph_df[graph_df['title_x'].isin(res.title_y.to_list())]
            g=res.groupby('title_x').apply(lambda x : x.sort_values(by = ['count'], ascending = False)).reset_index(drop=True)
        #ind=res.groupby('title_x')['count'].transform(max)== res['count']   
   
        #res=res[ind]
            res=g.groupby('title_x').head(2)
        
    
            a=res.values.tolist()
      
            edge_width = [ (m,n,  {'width': value/10}) 
                  for (u, v, m,n,a1,a2,a3,a4,value)  in a if v not in c and m!=n ]
            for gg in a:
                c.append(gg[1])
 

            G_new.add_edges_from(edge_width,title='')
  
 
        nt = Network(height="500px", width="100%", bgcolor="#222222", font_color="white", notebook=True,directed=True)

        
        aaaa=list(G_new.nodes)
        aaaa.sort(reverse=False)
        nt.add_nodes(aaaa,                 
        color = df_with_columns[df_with_columns['title_x'].isin(aaaa)].drop_duplicates(subset='title_x').sort_values(by='title_x')['0_x'].to_list())
        nt.from_nx(G_new)
    except:
        nt = Network(height="500px", width="100%", bgcolor="#222222", font_color="white", notebook=True,directed=True)

        aaaa=list(G_new.nodes)
        aaaa.sort(reverse=False)
        nt.add_nodes(aaaa,                 
        color = df_with_columns[df_with_columns['title_x'].isin(aaaa)].drop_duplicates(subset='title_x').sort_values(by='title_x')['0_x'].to_list())
            
        nt.from_nx(G_new)
      
  

    for edge in nt.edges:
        
        edge['title']='Количество переходов'+' ' +str(edge['width']*10)
        #edge["value"] = len(neighbor_map[node["id"]])
    for n in nt.nodes:
        if n['id']==INIT_ROLE:    
            n['font']['color']='red'
        
        

    
    return nt.show(str(INIT_ROLE)+'.html')
# Out:
# interactive(children=(Dropdown(description='INIT_ROLE', options=('Data science – обучение на курсе data scient…
